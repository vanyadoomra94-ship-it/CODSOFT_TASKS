# %%
## CODSOFT Python Programming Internship
## Task 3: Password Generator

# %%
import random
import string

print("=================================")
print("      PASSWORD GENERATOR")
print("=================================")

# Ask the user for password length
length = int(input("Enter password length: "))

# Character sets
letters = string.ascii_letters
numbers = string.digits
special_characters = string.punctuation

# Combine all characters
characters = letters + numbers + special_characters

# Generate password
password = ""

for i in range(length):
    password += random.choice(characters)

# Display password
print("\nGenerated Password:", password)
# Out:
# =================================
#       PASSWORD GENERATOR
# =================================
# Enter password length:  12
# Generated Password: TT/l*B!An~}9

# %%
### Conclusion
The Password Generator successfully creates random passwords
using letters, numbers, and special characters according to the
length specified by the user.
